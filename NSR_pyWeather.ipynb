# %%
import json 
import requests
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import openweathermapy as ow
import seaborn as sns

# %%
lat = []
lon = []
cities = set([])

while len(cities) < 1500:
    lati = (random.randrange(-90,90,1))
    long = (random.randrange(-180,180,1))
    city = citipy.nearest_city(lati,long)
    city = city.city_name
    lat.append(lati)
    lon.append(long)
    cities.add(city)
    
cities = list(cities)

# %%
api_key = "100e237d34c869e8b182ed6faeb536e9"
setting = {"units": "IMPERIAL", "appid": api_key}

# %%
weather_data = []
counter = []
count = 0

for city in cities:
    if count < 500:
        try:
            data = ow.get_current(city, **setting)
            weather_data.append(data)
            count = count + 1
            counter.append(count)
        except Exception as e:
            print(f"{city}: {e}, no weather data")
            continue
# Out:
# alotau: HTTP Error 404: Not Found, no weather data
# dolbeau: HTTP Error 404: Not Found, no weather data
# omutinskoye: HTTP Error 404: Not Found, no weather data
# rawannawi: HTTP Error 404: Not Found, no weather data
# linguere: HTTP Error 404: Not Found, no weather data
# kazalinsk: HTTP Error 404: Not Found, no weather data
# saryshagan: HTTP Error 404: Not Found, no weather data
# petropavl: HTTP Error 404: Not Found, no weather data
# miandoab: HTTP Error 404: Not Found, no weather data
# ruatoria: HTTP Error 404: Not Found, no weather data
# igarape-miri: HTTP Error 404: Not Found, no weather data
# tlahualilo: HTTP Error 404: Not Found, no weather data
# puerto pinasco: HTTP Error 404: Not Found, no weather data
# assela: HTTP Error 404: Not Found, no weather data
# gat: HTTP Error 404: Not Found, no weather data
# karamay: HTTP Error 404: Not Found, no weather data
# tabialan: HTTP Error 404: Not Found, no weather data
# aflu: HTTP Error 404: Not Found, no weather data
# marzuq: HTTP Error 404: Not Found, no weather data
# skalistyy: HTTP Error 404: Not Found, no weather data
# beba: HTTP Error 404: Not Found, no weather data
# turkistan: HTTP Error 404: Not Found, no weather data
# louisbourg: HTTP Error 404: Not Found, no weather data
# ambulu: HTTP Error 404: Not Found, no weather data
# lemesos: HTTP Error 404: Not Found, no weather data
# ambodifototra: HTTP Error 404: Not Found, no weather data
# phonhong: HTTP Error 404: Not Found, no weather data
# viramgam: HTTP Error 404: Not Found, no weather data
# sahrak: HTTP Error 404: Not Found, no weather data
# bereda: HTTP Error 404: Not Found, no weather data
# sorvag: HTTP Error 404: Not Found, no weather data
# bargal: HTTP Error 404: Not Found, no weather data
# ushtobe: HTTP Error 404: Not Found, no weather data
# sergiyevsk: HTTP Error 404: Not Found, no weather data
# fort saint john: HTTP Error 404: Not Found, no weather data
# hvammstangi: HTTP Error 404: Not Found, no weather data
# ritto: HTTP Error 404: Not Found, no weather data
# acapulco: HTTP Error 404: Not Found, no weather data
# huazolotitlan: HTTP Error 404: Not Found, no weather data
# timbangan: HTTP Error 404: Not Found, no weather data
# nikolskoye: HTTP Error 404: Not Found, no weather data
# kaduqli: HTTP Error 404: Not Found, no weather data
# staryy biser: HTTP Error 404: Not Found, no weather data
# solovetskiy: HTTP Error 404: Not Found, no weather data
# tunxi: HTTP Error 404: Not Found, no weather data
# nguiu: HTTP Error 404: Not Found, no weather data
# mooi river: HTTP Error 404: Not Found, no weather data
# asfi: HTTP Error 404: Not Found, no weather data
# karkaralinsk: HTTP Error 404: Not Found, no weather data
# umzimvubu: HTTP Error 404: Not Found, no weather data
# chlorakas: HTTP Error 404: Not Found, no weather data
# henties bay: HTTP Error 404: Not Found, no weather data
# bur gabo: HTTP Error 404: Not Found, no weather data
# jomalig: HTTP Error 404: Not Found, no weather data
# bokspits: HTTP Error 404: Not Found, no weather data
# amparai: HTTP Error 404: Not Found, no weather data
# banmo: HTTP Error 404: Not Found, no weather data
# wazzan: HTTP Error 404: Not Found, no weather data
# garowe: HTTP Error 404: Not Found, no weather data
# bayir: HTTP Error 404: Not Found, no weather data
# lethem: HTTP Error 404: Not Found, no weather data
# wulanhaote: HTTP Error 404: Not Found, no weather data
# chaa-khol: HTTP Error 404: Not Found, no weather data
# dujuma: HTTP Error 404: Not Found, no weather data
# sumbawa: HTTP Error 404: Not Found, no weather data
# kismayo: HTTP Error 404: Not Found, no weather data
# erenhot: HTTP Error 404: Not Found, no weather data
# tawkar: HTTP Error 404: Not Found, no weather data
# balykshi: HTTP Error 404: Not Found, no weather data
# waterfoot: HTTP Error 404: Not Found, no weather data
# khani: HTTP Error 404: Not Found, no weather data
# paradwip: HTTP Error 404: Not Found, no weather data
# raudeberg: HTTP Error 404: Not Found, no weather data
# zhanakorgan: HTTP Error 404: Not Found, no weather data
# avera: HTTP Error 404: Not Found, no weather data

# %%
weather_data
# Out:
# [{'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -22.09, 'lon': -70.2},
#   'dt': 1511045803,
#   'id': 3869716,
#   'main': {'grnd_level': 944.29,
#    'humidity': 92,
#    'pressure': 944.29,
#    'sea_level': 1027.24,
#    'temp': 58.62,
#    'temp_max': 58.62,
#    'temp_min': 58.62},
#   'name': 'Tocopilla',
#   'sys': {'country': 'CL',
#    'message': 0.1721,
#    'sunrise': 1510998552,
#    'sunset': 1511046211},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 209.005, 'speed': 4.38}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 18.58, 'lon': -92.65},
#   'dt': 1511041560,
#   'id': 3527545,
#   'main': {'humidity': 54,
#    'pressure': 1011,
#    'temp': 84.2,
#    'temp_max': 84.2,
#    'temp_min': 84.2},
#   'name': 'Frontera',
#   'sys': {'country': 'MX',
#    'id': 4029,
#    'message': 0.1664,
#    'sunrise': 1511007581,
#    'sunset': 1511047936,
#    'type': 1},
#   'visibility': 11265,
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03d',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 40, 'speed': 6.93}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 45.52, 'lon': -122.68},
#   'dt': 1511042160,
#   'id': 5746545,
#   'main': {'humidity': 62,
#    'pressure': 1023,
#    'temp': 49.08,
#    'temp_max': 51.8,
#    'temp_min': 42.8},
#   'name': 'Portland',
#   'sys': {'country': 'US',
#    'id': 2274,
#    'message': 0.1738,
#    'sunrise': 1511018143,
#    'sunset': 1511051774,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04d',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 110, 'speed': 5.82}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 56.94, 'lon': 60.9},
#   'dt': 1511042400,
#   'id': 1490962,
#   'main': {'humidity': 92,
#    'pressure': 1018,
#    'temp': 30.2,
#    'temp_max': 30.2,
#    'temp_min': 30.2},
#   'name': 'Staropyshminsk',
#   'sys': {'country': 'RU',
#    'id': 7318,
#    'message': 0.0094,
#    'sunrise': 1510976742,
#    'sunset': 1511005032,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'light shower snow',
#     'icon': '13n',
#     'id': 620,
#     'main': 'Snow'}],
#   'wind': {'deg': 230, 'speed': 8.95}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': 4.77, 'lon': 33.59},
#   'dt': 1511045805,
#   'id': 372884,
#   'main': {'grnd_level': 946.64,
#    'humidity': 43,
#    'pressure': 946.64,
#    'sea_level': 1020.84,
#    'temp': 74.01,
#    'temp_max': 74.01,
#    'temp_min': 74.01},
#   'name': 'Kapoeta',
#   'sys': {'country': 'SS',
#    'message': 0.165,
#    'sunrise': 1510976050,
#    'sunset': 1511018869},
#   'weather': [{'description': 'clear sky',
#     'icon': '02n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 140.505, 'speed': 7.4}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': -21.22, 'lon': 48.33},
#   'dt': 1511045805,
#   'id': 1061335,
#   'main': {'grnd_level': 1027.21,
#    'humidity': 100,
#    'pressure': 1027.21,
#    'sea_level': 1028.62,
#    'temp': 74.91,
#    'temp_max': 74.91,
#    'temp_min': 74.91},
#   'name': 'Mananjary',
#   'rain': {'3h': 0.7325},
#   'sys': {'country': 'MG',
#    'message': 0.0047,
#    'sunrise': 1510970197,
#    'sunset': 1511017662},
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 159.005, 'speed': 4.5}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': -28.87, 'lon': 153.57},
#   'dt': 1511045531,
#   'id': 2177069,
#   'main': {'grnd_level': 1027.62,
#    'humidity': 100,
#    'pressure': 1027.62,
#    'sea_level': 1032.96,
#    'temp': 70.28,
#    'temp_max': 70.28,
#    'temp_min': 70.28},
#   'name': 'Ballina',
#   'sys': {'country': 'AU',
#    'message': 0.1646,
#    'sunrise': 1510944125,
#    'sunset': 1510993217},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 115.505, 'speed': 13.78}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 50.15, 'lon': -5.07},
#   'dt': 1511041800,
#   'id': 2649715,
#   'main': {'humidity': 87,
#    'pressure': 1024,
#    'temp': 53.6,
#    'temp_max': 53.6,
#    'temp_min': 53.6},
#   'name': 'Falmouth',
#   'sys': {'country': 'GB',
#    'id': 5070,
#    'message': 0.1649,
#    'sunrise': 1510990804,
#    'sunset': 1511022648,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 280, 'speed': 13.87}},
#  {'base': 'stations',
#   'clouds': {'all': 44},
#   'cod': 200,
#   'coord': {'lat': 60.15, 'lon': -1.15},
#   'dt': 1511043600,
#   'id': 2644605,
#   'main': {'humidity': 75,
#    'pressure': 1011,
#    'temp': 42.8,
#    'temp_max': 42.8,
#    'temp_min': 42.8},
#   'name': 'Lerwick',
#   'sys': {'country': 'GB',
#    'id': 5126,
#    'message': 0.1649,
#    'sunrise': 1510992818,
#    'sunset': 1511018741,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 330, 'speed': 23.04}},
#  {'base': 'stations',
#   'clouds': {'all': 80},
#   'cod': 200,
#   'coord': {'lat': 51.36, 'lon': 112.48},
#   'dt': 1511045806,
#   'id': 2014369,
#   'main': {'grnd_level': 908.14,
#    'humidity': 74,
#    'pressure': 908.14,
#    'sea_level': 1040.58,
#    'temp': 14.66,
#    'temp_max': 14.66,
#    'temp_min': 14.66},
#   'name': 'Ulety',
#   'sys': {'country': 'RU',
#    'message': 0.1658,
#    'sunrise': 1510962832,
#    'sunset': 1510994185},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 298.005, 'speed': 10.76}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 44.29, 'lon': -105.5},
#   'dt': 1511041980,
#   'id': 5826027,
#   'main': {'humidity': 30,
#    'pressure': 1020,
#    'temp': 41,
#    'temp_max': 41,
#    'temp_min': 41},
#   'name': 'Gillette',
#   'sys': {'country': 'US',
#    'id': 3080,
#    'message': 0.1671,
#    'sunrise': 1511013801,
#    'sunset': 1511047870,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 300, 'speed': 9.17}},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': 24.42, 'lon': 81.88},
#   'dt': 1511045807,
#   'id': 1256369,
#   'main': {'grnd_level': 991.79,
#    'humidity': 76,
#    'pressure': 991.79,
#    'sea_level': 1026.96,
#    'temp': 68.3,
#    'temp_max': 68.3,
#    'temp_min': 68.3},
#   'name': 'Sidhi',
#   'rain': {'3h': 0.1275},
#   'sys': {'country': 'IN',
#    'message': 0.165,
#    'sunrise': 1510966244,
#    'sunset': 1511005481},
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 311.005, 'speed': 5.39}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 40.6, 'lon': -124.16},
#   'dt': 1511044500,
#   'id': 5563839,
#   'main': {'humidity': 54,
#    'pressure': 1022,
#    'temp': 54.27,
#    'temp_max': 55.4,
#    'temp_min': 53.6},
#   'name': 'Fortuna',
#   'sys': {'country': 'US',
#    'id': 386,
#    'message': 0.1649,
#    'sunrise': 1511017692,
#    'sunset': 1511052939,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 290, 'speed': 4.7}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 25.7, 'lon': 100.18},
#   'dt': 1511045533,
#   'id': 1814093,
#   'main': {'grnd_level': 787.6,
#    'humidity': 100,
#    'pressure': 787.6,
#    'sea_level': 1027.36,
#    'temp': 40.85,
#    'temp_max': 40.85,
#    'temp_min': 40.85},
#   'name': 'Dali',
#   'sys': {'country': 'CN',
#    'message': 0.1691,
#    'sunrise': 1510961981,
#    'sunset': 1511000958},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 250.005, 'speed': 1.92}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 11.18, 'lon': -4.3},
#   'dt': 1511042400,
#   'id': 2362344,
#   'main': {'humidity': 30,
#    'pressure': 1012,
#    'temp': 80.6,
#    'temp_max': 80.6,
#    'temp_min': 80.6},
#   'name': 'Bobo-Dioulasso',
#   'sys': {'country': 'BF',
#    'id': 6246,
#    'message': 0.1657,
#    'sunrise': 1510985699,
#    'sunset': 1511027407,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 20, 'speed': 2.24}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': -41.07, 'lon': 145.92},
#   'dt': 1511045534,
#   'id': 2173125,
#   'main': {'grnd_level': 1035.8,
#    'humidity': 92,
#    'pressure': 1035.8,
#    'sea_level': 1038.51,
#    'temp': 61.14,
#    'temp_max': 61.14,
#    'temp_min': 61.14},
#   'name': 'Burnie',
#   'sys': {'country': 'AU',
#    'message': 0.1655,
#    'sunrise': 1510944311,
#    'sunset': 1510996719},
#   'weather': [{'description': 'clear sky',
#     'icon': '02n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 95.5046, 'speed': 17.25}},
#  {'base': 'stations',
#   'clouds': {'all': 32},
#   'cod': 200,
#   'coord': {'lat': 32.69, 'lon': 128.84},
#   'dt': 1511045809,
#   'id': 1863997,
#   'main': {'grnd_level': 1038.72,
#    'humidity': 100,
#    'pressure': 1038.72,
#    'sea_level': 1039.04,
#    'temp': 54.39,
#    'temp_max': 54.39,
#    'temp_min': 54.39},
#   'name': 'Fukue',
#   'sys': {'country': 'JP',
#    'message': 0.1674,
#    'sunrise': 1510955874,
#    'sunset': 1510993303},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 353.505, 'speed': 27.54}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 13.56, 'lon': 7.05},
#   'dt': 1511045810,
#   'id': 2438774,
#   'main': {'grnd_level': 978.34,
#    'humidity': 56,
#    'pressure': 978.34,
#    'sea_level': 1022.3,
#    'temp': 69.65,
#    'temp_max': 69.65,
#    'temp_min': 69.65},
#   'name': 'Tibiri',
#   'sys': {'country': 'NE',
#    'message': 0.1671,
#    'sunrise': 1510983185,
#    'sunset': 1511024471},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 107.505, 'speed': 3.94}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': 32.44, 'lon': 105.82},
#   'dt': 1511045810,
#   'id': 1806466,
#   'main': {'grnd_level': 935.54,
#    'humidity': 100,
#    'pressure': 935.54,
#    'sea_level': 1038.51,
#    'temp': 41.75,
#    'temp_max': 41.75,
#    'temp_min': 41.75},
#   'name': 'Guangyuan',
#   'rain': {'3h': 0.4475},
#   'sys': {'country': 'CN',
#    'message': 0.1662,
#    'sunrise': 1510961372,
#    'sunset': 1510998856},
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 22.0046, 'speed': 2.71}},
#  {'base': 'stations',
#   'clouds': {'all': 64},
#   'cod': 200,
#   'coord': {'lat': -18.17, 'lon': -47.95},
#   'dt': 1511045811,
#   'id': 3466696,
#   'main': {'grnd_level': 938.05,
#    'humidity': 90,
#    'pressure': 938.05,
#    'sea_level': 1022.87,
#    'temp': 70.41,
#    'temp_max': 70.41,
#    'temp_min': 70.41},
#   'name': 'Catalao',
#   'sys': {'country': 'BR',
#    'message': 0.1647,
#    'sunrise': 1510993601,
#    'sunset': 1511040477},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 30.5046, 'speed': 2.82}},
#  {'base': 'stations',
#   'clouds': {'all': 64},
#   'cod': 200,
#   'coord': {'lat': 61.15, 'lon': 149.63},
#   'dt': 1511045811,
#   'id': 2120047,
#   'main': {'grnd_level': 919.73,
#    'humidity': 70,
#    'pressure': 919.73,
#    'sea_level': 1031.98,
#    'temp': -12.08,
#    'temp_max': -12.08,
#    'temp_min': -12.08},
#   'name': 'Ust-Omchug',
#   'sys': {'country': 'RU',
#    'message': 0.0044,
#    'sunrise': 1510956992,
#    'sunset': 1510982180},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 30.0046, 'speed': 3.38}},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': -20.57, 'lon': 164.28},
#   'dt': 1511045537,
#   'id': 2140558,
#   'main': {'grnd_level': 1008.74,
#    'humidity': 74,
#    'pressure': 1008.74,
#    'sea_level': 1024.61,
#    'temp': 75.23,
#    'temp_max': 75.23,
#    'temp_min': 75.23},
#   'name': 'Koumac',
#   'sys': {'country': 'NC',
#    'message': 0.1669,
#    'sunrise': 1510942437,
#    'sunset': 1510989756},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 89.0046, 'speed': 4.83}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 31.76, 'lon': 13.99},
#   'dt': 1511045812,
#   'id': 2218840,
#   'main': {'grnd_level': 989.2,
#    'humidity': 84,
#    'pressure': 989.2,
#    'sea_level': 1032.96,
#    'temp': 45.26,
#    'temp_max': 45.26,
#    'temp_min': 45.26},
#   'name': 'Bani Walid',
#   'sys': {'country': 'LY',
#    'message': 0.1664,
#    'sunrise': 1510983345,
#    'sunset': 1511020969},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 300.005, 'speed': 8.86}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': -8.65, 'lon': 115.22},
#   'dt': 1511042400,
#   'id': 1645528,
#   'main': {'humidity': 94,
#    'pressure': 1007,
#    'temp': 77,
#    'temp_max': 77,
#    'temp_min': 77},
#   'name': 'Denpasar',
#   'sys': {'country': 'ID',
#    'id': 8000,
#    'message': 0.0041,
#    'sunrise': 1510955310,
#    'sunset': 1511000428,
#    'type': 1},
#   'visibility': 8000,
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'speed': 1.12}},
#  {'base': 'stations',
#   'clouds': {'all': 48},
#   'cod': 200,
#   'coord': {'lat': 66.42, 'lon': 112.4},
#   'dt': 1511045813,
#   'id': 2014624,
#   'main': {'grnd_level': 981.01,
#    'humidity': 64,
#    'pressure': 981.01,
#    'sea_level': 1038.51,
#    'temp': -9.02,
#    'temp_max': -9.02,
#    'temp_min': -9.02},
#   'name': 'Udachnyy',
#   'sys': {'country': 'RU',
#    'message': 0.1665,
#    'sunrise': 1510969041,
#    'sunset': 1510987997},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 289.005, 'speed': 3.27}},
#  {'base': 'stations',
#   'clouds': {'all': 68},
#   'cod': 200,
#   'coord': {'lat': 1.67, 'lon': 31.71},
#   'dt': 1511045813,
#   'id': 229362,
#   'main': {'grnd_level': 907.33,
#    'humidity': 95,
#    'pressure': 907.33,
#    'sea_level': 1022.54,
#    'temp': 64.29,
#    'temp_max': 64.29,
#    'temp_min': 64.29},
#   'name': 'Masindi',
#   'rain': {'3h': 1.7075},
#   'sys': {'country': 'UG',
#    'message': 0.1647,
#    'sunrise': 1510976238,
#    'sunset': 1511019585},
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 176.505, 'speed': 0.47}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': 57.11, 'lon': 12.25},
#   'dt': 1511043600,
#   'id': 2664996,
#   'main': {'humidity': 81,
#    'pressure': 995,
#    'temp': 42.78,
#    'temp_max': 44.6,
#    'temp_min': 41},
#   'name': 'Varberg',
#   'sys': {'country': 'SE',
#    'id': 5398,
#    'message': 0.1643,
#    'sunrise': 1510988490,
#    'sunset': 1511016640,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 260, 'gust': 14.4, 'speed': 20.8}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': -11.38, 'lon': 43.28},
#   'dt': 1511045814,
#   'id': 921786,
#   'main': {'grnd_level': 1016.76,
#    'humidity': 100,
#    'pressure': 1016.76,
#    'sea_level': 1024.61,
#    'temp': 78.87,
#    'temp_max': 78.87,
#    'temp_min': 78.87},
#   'name': 'Mitsamiouli',
#   'sys': {'country': 'KM',
#    'message': 0.1721,
#    'sunrise': 1510972335,
#    'sunset': 1511017941},
#   'weather': [{'description': 'few clouds',
#     'icon': '02n',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 100.505, 'speed': 8.3}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 14.9, 'lon': -24.5},
#   'dt': 1511045815,
#   'id': 3374210,
#   'main': {'grnd_level': 1015.22,
#    'humidity': 100,
#    'pressure': 1015.22,
#    'sea_level': 1026.88,
#    'temp': 77.07,
#    'temp_max': 77.07,
#    'temp_min': 77.07},
#   'name': 'Sao Filipe',
#   'sys': {'country': 'CV',
#    'message': 0.1647,
#    'sunrise': 1510990879,
#    'sunset': 1511031922},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 48.0046, 'speed': 10.98}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -15.2, 'lon': 12.15},
#   'dt': 1511045815,
#   'id': 3347019,
#   'main': {'grnd_level': 1020.48,
#    'humidity': 100,
#    'pressure': 1020.48,
#    'sea_level': 1024.45,
#    'temp': 69.47,
#    'temp_max': 69.47,
#    'temp_min': 69.47},
#   'name': 'Namibe',
#   'sys': {'country': 'AO',
#    'message': 0.1632,
#    'sunrise': 1510979459,
#    'sunset': 1511025765},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 137.505, 'speed': 0.69}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': 14.44, 'lon': -11.43},
#   'dt': 1511045816,
#   'id': 2455518,
#   'main': {'grnd_level': 1011.65,
#    'humidity': 44,
#    'pressure': 1011.65,
#    'sea_level': 1024.24,
#    'temp': 72.35,
#    'temp_max': 72.35,
#    'temp_min': 72.35},
#   'name': 'Kayes',
#   'sys': {'country': 'ML',
#    'message': 0.1655,
#    'sunrise': 1510987700,
#    'sunset': 1511028827},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 30.5046, 'speed': 4.5}},
#  {'base': 'stations',
#   'clouds': {'all': 44},
#   'cod': 200,
#   'coord': {'lat': 37.08, 'lon': 41.22},
#   'dt': 1511042400,
#   'id': 303750,
#   'main': {'humidity': 45,
#    'pressure': 1019,
#    'temp': 48.2,
#    'temp_max': 48.2,
#    'temp_min': 48.2},
#   'name': 'Nusaybin',
#   'sys': {'country': 'TR',
#    'id': 7168,
#    'message': 0.1658,
#    'sunrise': 1510977472,
#    'sunset': 1511013767,
#    'type': 1},
#   'visibility': 7000,
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 350, 'speed': 5.82}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 40.68, 'lon': -122.37},
#   'dt': 1511042040,
#   'id': 5571109,
#   'main': {'humidity': 25,
#    'pressure': 1022,
#    'temp': 62.6,
#    'temp_max': 62.6,
#    'temp_min': 62.6},
#   'name': 'Shasta Lake',
#   'sys': {'country': 'US',
#    'id': 460,
#    'message': 0.1642,
#    'sunrise': 1511017274,
#    'sunset': 1511052498,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 8.50461, 'speed': 2.15}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 55.1, 'lon': -105.28},
#   'dt': 1511042400,
#   'id': 6050066,
#   'main': {'humidity': 66,
#    'pressure': 1013,
#    'temp': 10.4,
#    'temp_max': 10.4,
#    'temp_min': 10.4},
#   'name': 'La Ronge',
#   'sys': {'country': 'CA',
#    'id': 3914,
#    'message': 0.1663,
#    'sunrise': 1511016122,
#    'sunset': 1511045434,
#    'type': 1},
#   'visibility': 24140,
#   'weather': [{'description': 'few clouds',
#     'icon': '02d',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 260, 'speed': 6.93}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 38.53, 'lon': -28.64},
#   'dt': 1511042400,
#   'id': 8013523,
#   'main': {'humidity': 94,
#    'pressure': 1014,
#    'temp': 68,
#    'temp_max': 68,
#    'temp_min': 68},
#   'name': 'Horta (Angústias)',
#   'sys': {'country': 'PT',
#    'id': 5950,
#    'message': 0.1837,
#    'sunrise': 1510994449,
#    'sunset': 1511030326,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 120, 'speed': 10.29}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 11.28, 'lon': -15.83},
#   'dt': 1511042400,
#   'id': 2374583,
#   'main': {'humidity': 73,
#    'pressure': 1010,
#    'temp': 77,
#    'temp_max': 77,
#    'temp_min': 77},
#   'name': 'Bubaque',
#   'sys': {'country': 'GW',
#    'id': 6118,
#    'message': 0.1656,
#    'sunrise': 1510988476,
#    'sunset': 1511030165,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 320, 'speed': 4.7}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 46.78, 'lon': -92.11},
#   'dt': 1511044500,
#   'id': 5024719,
#   'main': {'humidity': 63,
#    'pressure': 1012,
#    'temp': 26.29,
#    'temp_max': 28.4,
#    'temp_min': 23},
#   'name': 'Duluth',
#   'sys': {'country': 'US',
#    'id': 3027,
#    'message': 0.2444,
#    'sunrise': 1511011031,
#    'sunset': 1511044209,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 320, 'gust': 8.2, 'speed': 13.87}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 13.73, 'lon': 5.3},
#   'dt': 1511045819,
#   'id': 2337680,
#   'main': {'grnd_level': 986.04,
#    'humidity': 58,
#    'pressure': 986.04,
#    'sea_level': 1021.89,
#    'temp': 70.37,
#    'temp_max': 70.37,
#    'temp_min': 70.37},
#   'name': 'Illela',
#   'sys': {'country': 'NG',
#    'message': 0.1636,
#    'sunrise': 1510983620,
#    'sunset': 1511024876},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 273.005, 'speed': 2.82}},
#  {'base': 'stations',
#   'clouds': {'all': 36},
#   'cod': 200,
#   'coord': {'lat': 45.09, 'lon': 133.51},
#   'dt': 1511045819,
#   'id': 2022064,
#   'main': {'grnd_level': 1004.68,
#    'humidity': 77,
#    'pressure': 1004.68,
#    'sea_level': 1035.15,
#    'temp': -3.89,
#    'temp_max': -3.89,
#    'temp_min': -3.89},
#   'name': 'Kirovskiy',
#   'sys': {'country': 'RU',
#    'message': 0.0055,
#    'sunrise': 1510956524,
#    'sunset': 1510990402},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 320.005, 'speed': 4.38}},
#  {'base': 'stations',
#   'clouds': {'all': 24},
#   'cod': 200,
#   'coord': {'lat': -2.67, 'lon': 141.3},
#   'dt': 1511045820,
#   'id': 2084442,
#   'main': {'grnd_level': 1021.38,
#    'humidity': 100,
#    'pressure': 1021.38,
#    'sea_level': 1021.53,
#    'temp': 84.36,
#    'temp_max': 84.36,
#    'temp_min': 84.36},
#   'name': 'Vanimo',
#   'sys': {'country': 'PG',
#    'message': 0.172,
#    'sunrise': 1510949565,
#    'sunset': 1510993649},
#   'weather': [{'description': 'few clouds',
#     'icon': '02n',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 272.005, 'speed': 10.2}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': -25.24, 'lon': 130.99},
#   'dt': 1511042400,
#   'id': 6355222,
#   'main': {'humidity': 64,
#    'pressure': 1013,
#    'temp': 75.2,
#    'temp_max': 75.2,
#    'temp_min': 75.2},
#   'name': 'Yulara',
#   'rain': {'3h': 0.1425},
#   'sys': {'country': 'AU',
#    'id': 8160,
#    'message': 0.1659,
#    'sunrise': 1510949946,
#    'sunset': 1510998233,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 160, 'speed': 9.17}},
#  {'base': 'stations',
#   'clouds': {'all': 12},
#   'cod': 200,
#   'coord': {'lat': 8.93, 'lon': 8.6},
#   'dt': 1511045821,
#   'id': 2319257,
#   'main': {'grnd_level': 971.85,
#    'humidity': 75,
#    'pressure': 971.85,
#    'sea_level': 1022.26,
#    'temp': 72.08,
#    'temp_max': 72.08,
#    'temp_min': 72.08},
#   'name': 'Wamba',
#   'sys': {'country': 'NG',
#    'message': 0.1698,
#    'sunrise': 1510982406,
#    'sunset': 1511024508},
#   'weather': [{'description': 'few clouds',
#     'icon': '02n',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 160.505, 'speed': 3.15}},
#  {'base': 'stations',
#   'clouds': {'all': 44},
#   'cod': 200,
#   'coord': {'lat': 44.17, 'lon': 133.86},
#   'dt': 1511045821,
#   'id': 2025286,
#   'main': {'grnd_level': 990.01,
#    'humidity': 63,
#    'pressure': 990.01,
#    'sea_level': 1034.38,
#    'temp': 3.32,
#    'temp_max': 3.32,
#    'temp_min': 3.32},
#   'name': 'Chuguyevka',
#   'sys': {'country': 'RU',
#    'message': 0.1666,
#    'sunrise': 1510956282,
#    'sunset': 1510990477},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 315.005, 'speed': 5.95}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -23.68, 'lon': 22.79},
#   'dt': 1511045822,
#   'id': 933692,
#   'main': {'grnd_level': 901.09,
#    'humidity': 22,
#    'pressure': 901.09,
#    'sea_level': 1027.65,
#    'temp': 58.58,
#    'temp_max': 58.58,
#    'temp_min': 58.58},
#   'name': 'Kang',
#   'sys': {'country': 'BW',
#    'message': 0.1653,
#    'sunrise': 1510976074,
#    'sunset': 1511024048},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 92.5046, 'speed': 9.19}},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': -14.74, 'lon': -50.57},
#   'dt': 1511045543,
#   'id': 3456642,
#   'main': {'grnd_level': 968.94,
#    'humidity': 94,
#    'pressure': 968.94,
#    'sea_level': 1023.19,
#    'temp': 71.18,
#    'temp_max': 71.18,
#    'temp_min': 71.18},
#   'name': 'Mozarlandia',
#   'rain': {'3h': 4.325},
#   'sys': {'country': 'BR',
#    'message': 0.1678,
#    'sunrise': 1510994554,
#    'sunset': 1511040780},
#   'weather': [{'description': 'moderate rain',
#     'icon': '10n',
#     'id': 501,
#     'main': 'Rain'}],
#   'wind': {'deg': 4.00461, 'speed': 1.14}},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': 63.37, 'lon': 47.92},
#   'dt': 1511045823,
#   'id': 576093,
#   'main': {'grnd_level': 999.74,
#    'humidity': 76,
#    'pressure': 999.74,
#    'sea_level': 1017.64,
#    'temp': 32.79,
#    'temp_max': 32.79,
#    'temp_min': 32.79},
#   'name': 'Blagoyevo',
#   'sys': {'country': 'RU',
#    'message': 0.0047,
#    'sunrise': 1510982541,
#    'sunset': 1511005456},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 242.005, 'speed': 6.96}},
#  {'base': 'stations',
#   'clouds': {'all': 76},
#   'cod': 200,
#   'coord': {'lat': 21.85, 'lon': 111.97},
#   'dt': 1511045543,
#   'id': 1806408,
#   'main': {'grnd_level': 1029.4,
#    'humidity': 100,
#    'pressure': 1029.4,
#    'sea_level': 1030.69,
#    'temp': 67.13,
#    'temp_max': 67.13,
#    'temp_min': 67.13},
#   'name': 'Yangjiang',
#   'sys': {'country': 'CN',
#    'message': 0.1648,
#    'sunrise': 1510958764,
#    'sunset': 1510998518},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 39.5046, 'speed': 24.74}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 40.66, 'lon': -73.58},
#   'dt': 1511043300,
#   'id': 5117949,
#   'main': {'humidity': 76,
#    'pressure': 1004,
#    'temp': 50,
#    'temp_max': 55.4,
#    'temp_min': 42.8},
#   'name': 'Freeport',
#   'sys': {'country': 'US',
#    'id': 2100,
#    'message': 0.1746,
#    'sunrise': 1511005552,
#    'sunset': 1511040797,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'},
#    {'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'},
#    {'description': 'drizzle', 'icon': '09n', 'id': 301, 'main': 'Drizzle'}],
#   'wind': {'deg': 210, 'speed': 12.75}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 43.61, 'lon': 122.27},
#   'dt': 1511045824,
#   'id': 2034400,
#   'main': {'grnd_level': 1021.62,
#    'humidity': 54,
#    'pressure': 1021.62,
#    'sea_level': 1044.35,
#    'temp': 3.86,
#    'temp_max': 3.86,
#    'temp_min': 3.86},
#   'name': 'Tongliao',
#   'sys': {'country': 'CN',
#    'message': 0.1661,
#    'sunrise': 1510958973,
#    'sunset': 1510993350},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 315.505, 'speed': 7.18}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -33.01, 'lon': 17.94},
#   'dt': 1511042400,
#   'id': 3361934,
#   'main': {'humidity': 82,
#    'pressure': 1016,
#    'temp': 57.2,
#    'temp_max': 57.2,
#    'temp_min': 57.2},
#   'name': 'Saldanha',
#   'sys': {'country': 'ZA',
#    'id': 6575,
#    'message': 0.1637,
#    'sunrise': 1510976166,
#    'sunset': 1511026293,
#    'type': 1},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 170, 'speed': 1.12}},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': 68.05, 'lon': 166.44},
#   'dt': 1511045825,
#   'id': 2126682,
#   'main': {'grnd_level': 959.37,
#    'humidity': 70,
#    'pressure': 959.37,
#    'sea_level': 1014.88,
#    'temp': 5.84,
#    'temp_max': 5.84,
#    'temp_min': 5.84},
#   'name': 'Bilibino',
#   'sys': {'country': 'RU',
#    'message': 0.1664,
#    'sunrise': 1510957524,
#    'sunset': 1510973567},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 268.005, 'speed': 7.96}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': 62.86, 'lon': 42.71},
#   'dt': 1511045826,
#   'id': 577240,
#   'main': {'grnd_level': 1009.38,
#    'humidity': 94,
#    'pressure': 1009.38,
#    'sea_level': 1016.62,
#    'temp': 34.91,
#    'temp_max': 34.91,
#    'temp_min': 34.91},
#   'name': 'Bereznik',
#   'rain': {'3h': 0.3625},
#   'sys': {'country': 'RU',
#    'message': 0.2457,
#    'sunrise': 1510983521,
#    'sunset': 1511006978},
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 220.505, 'speed': 7.52}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 21.97, 'lon': 70.8},
#   'dt': 1511045826,
#   'id': 1270994,
#   'main': {'grnd_level': 1010.11,
#    'humidity': 62,
#    'pressure': 1010.11,
#    'sea_level': 1027.69,
#    'temp': 58.13,
#    'temp_max': 58.13,
#    'temp_min': 58.13},
#   'name': 'Gondal',
#   'sys': {'country': 'IN',
#    'message': 0.167,
#    'sunrise': 1510968661,
#    'sunset': 1511008385},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 6.50461, 'speed': 8.97}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 51.38, 'lon': 1.39},
#   'dt': 1511043600,
#   'id': 2643044,
#   'main': {'humidity': 81,
#    'pressure': 1020,
#    'temp': 43.72,
#    'temp_max': 44.6,
#    'temp_min': 42.8},
#   'name': 'Margate',
#   'sys': {'country': 'GB',
#    'id': 5094,
#    'message': 0.1699,
#    'sunrise': 1510989529,
#    'sunset': 1511020820,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 270, 'speed': 6.93}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -34.43, 'lon': -58.58},
#   'dt': 1511042400,
#   'id': 3427761,
#   'main': {'humidity': 25,
#    'pressure': 1009,
#    'temp': 64.36,
#    'temp_max': 66.2,
#    'temp_min': 62.6},
#   'name': 'Tigre',
#   'sys': {'country': 'AR',
#    'id': 4694,
#    'message': 0.0043,
#    'sunrise': 1510994340,
#    'sunset': 1511044857,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 230, 'speed': 8.05}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 47.69, 'lon': -114.16},
#   'dt': 1511045828,
#   'id': 5671996,
#   'main': {'grnd_level': 875.64,
#    'humidity': 63,
#    'pressure': 875.64,
#    'sea_level': 1037.74,
#    'temp': 30.68,
#    'temp_max': 30.68,
#    'temp_min': 30.68},
#   'name': 'Polson',
#   'sys': {'country': 'US',
#    'message': 0.1684,
#    'sunrise': 1511016504,
#    'sunset': 1511049322},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 242.505, 'speed': 2.15}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': -7.91, 'lon': 39.67},
#   'dt': 1511045828,
#   'id': 157429,
#   'main': {'grnd_level': 1024.05,
#    'humidity': 100,
#    'pressure': 1024.05,
#    'sea_level': 1024.2,
#    'temp': 80.81,
#    'temp_max': 80.81,
#    'temp_min': 80.81},
#   'name': 'Kilindoni',
#   'sys': {'country': 'TZ',
#    'message': 0.1635,
#    'sunrise': 1510973508,
#    'sunset': 1511018500},
#   'weather': [{'description': 'clear sky',
#     'icon': '02n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 114.005, 'speed': 5.28}},
#  {'base': 'stations',
#   'clouds': {'all': 64},
#   'cod': 200,
#   'coord': {'lat': -0.95, 'lon': 100.35},
#   'dt': 1511045829,
#   'id': 1633419,
#   'main': {'grnd_level': 1017.89,
#    'humidity': 100,
#    'pressure': 1017.89,
#    'sea_level': 1023.31,
#    'temp': 77.79,
#    'temp_max': 77.79,
#    'temp_min': 77.79},
#   'name': 'Padang',
#   'rain': {'3h': 1.865},
#   'sys': {'country': 'ID',
#    'message': 0.17,
#    'sunrise': 1510959540,
#    'sunset': 1511003332},
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 316.505, 'speed': 6.06}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -9.09, 'lon': -78.58},
#   'dt': 1511045630,
#   'id': 3698304,
#   'main': {'grnd_level': 994.31,
#    'humidity': 82,
#    'pressure': 994.31,
#    'sea_level': 1025.58,
#    'temp': 63.35,
#    'temp_max': 63.35,
#    'temp_min': 63.35},
#   'name': 'Chimbote',
#   'sys': {'country': 'PE',
#    'message': 0.0067,
#    'sunrise': 1511001786,
#    'sunset': 1511046991},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 173.505, 'speed': 8.41}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 61.87, 'lon': 28.92},
#   'dt': 1511043600,
#   'id': 637293,
#   'main': {'humidity': 93,
#    'pressure': 999,
#    'temp': 39.2,
#    'temp_max': 39.2,
#    'temp_min': 39.2},
#   'name': 'Savonlinna',
#   'sys': {'country': 'FI',
#    'id': 5041,
#    'message': 0.1654,
#    'sunrise': 1510986345,
#    'sunset': 1511010776,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'light intensity shower rain',
#     'icon': '09n',
#     'id': 520,
#     'main': 'Rain'}],
#   'wind': {'deg': 170, 'speed': 5.82}},
#  {'base': 'stations',
#   'clouds': {'all': 24},
#   'cod': 200,
#   'coord': {'lat': 14.95, 'lon': -89.97},
#   'dt': 1511045830,
#   'id': 3590547,
#   'main': {'grnd_level': 894.77,
#    'humidity': 56,
#    'pressure': 894.77,
#    'sea_level': 1023.19,
#    'temp': 72.21,
#    'temp_max': 72.21,
#    'temp_min': 72.21},
#   'name': 'San Agustin Acasaguastlan',
#   'sys': {'country': 'GT',
#    'message': 0.1667,
#    'sunrise': 1511006602,
#    'sunset': 1511047630},
#   'weather': [{'description': 'few clouds',
#     'icon': '02d',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 39.5046, 'speed': 1.7}},
#  {'base': 'stations',
#   'clouds': {'all': 76},
#   'cod': 200,
#   'coord': {'lat': 67.45, 'lon': 153.68},
#   'dt': 1511045830,
#   'id': 2121025,
#   'main': {'grnd_level': 1012.71,
#    'humidity': 70,
#    'pressure': 1012.71,
#    'sea_level': 1023.72,
#    'temp': -1.73,
#    'temp_max': -1.73,
#    'temp_min': -1.73},
#   'name': 'Srednekolymsk',
#   'sys': {'country': 'RU',
#    'message': 0.1651,
#    'sunrise': 1510959998,
#    'sunset': 1510977220},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 237.505, 'speed': 8.52}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 4.93, 'lon': -52.33},
#   'dt': 1511044200,
#   'id': 3382160,
#   'main': {'humidity': 83,
#    'pressure': 1008,
#    'temp': 80.6,
#    'temp_max': 80.6,
#    'temp_min': 80.6},
#   'name': 'Cayenne',
#   'sys': {'country': 'GF',
#    'id': 4338,
#    'message': 0.1673,
#    'sunrise': 1510996689,
#    'sunset': 1511039478,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#     'icon': '02n',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 80, 'speed': 3.36}},
#  {'base': 'stations',
#   'clouds': {'all': 36},
#   'cod': 200,
#   'coord': {'lat': 6.8, 'lon': -1.08},
#   'dt': 1511045831,
#   'id': 2305537,
#   'main': {'grnd_level': 995.28,
#    'humidity': 97,
#    'pressure': 995.28,
#    'sea_level': 1024,
#    'temp': 71,
#    'temp_max': 71,
#    'temp_min': 71},
#   'name': 'Agogo',
#   'sys': {'country': 'GH',
#    'message': 0.1687,
#    'sunrise': 1510984546,
#    'sunset': 1511027016},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 216.505, 'speed': 2.82}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 27.91, 'lon': -15.45},
#   'dt': 1511044200,
#   'id': 2522325,
#   'main': {'humidity': 73,
#    'pressure': 1016,
#    'temp': 69.8,
#    'temp_max': 69.8,
#    'temp_min': 69.8},
#   'name': 'Aguimes',
#   'sys': {'country': 'ES',
#    'id': 5516,
#    'message': 0.1644,
#    'sunrise': 1510989981,
#    'sunset': 1511028469,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 30, 'speed': 13.87}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 30.48, 'lon': -115.95},
#   'dt': 1511045832,
#   'id': 3984997,
#   'main': {'grnd_level': 977.93,
#    'humidity': 45,
#    'pressure': 977.93,
#    'sea_level': 1029.55,
#    'temp': 72.21,
#    'temp_max': 72.21,
#    'temp_min': 72.21},
#   'name': 'San Quintin',
#   'sys': {'country': 'MX',
#    'message': 0.1641,
#    'sunrise': 1511014401,
#    'sunset': 1511052295},
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 286.505, 'speed': 4.05}},
#  {'base': 'stations',
#   'clouds': {'all': 12},
#   'cod': 200,
#   'coord': {'lat': 51.9, 'lon': 11.05},
#   'dt': 1511045833,
#   'id': 2911665,
#   'main': {'grnd_level': 1008.25,
#    'humidity': 91,
#    'pressure': 1008.25,
#    'sea_level': 1023.51,
#    'temp': 36.84,
#    'temp_max': 36.84,
#    'temp_min': 36.84},
#   'name': 'Halberstadt',
#   'sys': {'country': 'DE',
#    'message': 0.1656,
#    'sunrise': 1510987330,
#    'sunset': 1511018381},
#   'weather': [{'description': 'few clouds',
#     'icon': '02n',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 261.505, 'speed': 16.8}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 40.16, 'lon': -8.33},
#   'dt': 1511042400,
#   'id': 2738381,
#   'main': {'humidity': 100,
#    'pressure': 1020,
#    'temp': 48.2,
#    'temp_max': 48.2,
#    'temp_min': 48.2},
#   'name': 'Lata',
#   'sys': {'country': 'PT',
#    'id': 5953,
#    'message': 0.0064,
#    'sunrise': 1510989805,
#    'sunset': 1511025219,
#    'type': 1},
#   'visibility': 3500,
#   'weather': [{'description': 'mist',
#     'icon': '50n',
#     'id': 701,
#     'main': 'Mist'}],
#   'wind': {'speed': 2.24}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 45.12, 'lon': -95.04},
#   'dt': 1511043300,
#   'id': 5052916,
#   'main': {'humidity': 68,
#    'pressure': 1016,
#    'temp': 27.88,
#    'temp_max': 30.2,
#    'temp_min': 23},
#   'name': 'Willmar',
#   'sys': {'country': 'US',
#    'id': 1586,
#    'message': 0.1698,
#    'sunrise': 1511011432,
#    'sunset': 1511045216,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 320, 'gust': 12.9, 'speed': 24.16}},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': 50.95, 'lon': 46.97},
#   'dt': 1511045834,
#   'id': 541647,
#   'main': {'grnd_level': 1029,
#    'humidity': 95,
#    'pressure': 1029,
#    'sea_level': 1038.59,
#    'temp': 30.99,
#    'temp_max': 30.99,
#    'temp_min': 30.99},
#   'name': 'Krasnyy Kut',
#   'sys': {'country': 'RU',
#    'message': 0.1717,
#    'sunrise': 1510978479,
#    'sunset': 1511009989},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 157.505, 'speed': 9.19}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': -11.83, 'lon': 31.45},
#   'dt': 1511045834,
#   'id': 905846,
#   'main': {'grnd_level': 871.1,
#    'humidity': 70,
#    'pressure': 871.1,
#    'sea_level': 1024,
#    'temp': 67.4,
#    'temp_max': 67.4,
#    'temp_min': 67.4},
#   'name': 'Mpika',
#   'sys': {'country': 'ZM',
#    'message': 0.1652,
#    'sunrise': 1510975134,
#    'sunset': 1511020822},
#   'weather': [{'description': 'clear sky',
#     'icon': '02n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 128.505, 'speed': 9.98}},
#  {'base': 'stations',
#   'clouds': {'all': 44},
#   'cod': 200,
#   'coord': {'lat': -3.6, 'lon': 26.67},
#   'dt': 1511045835,
#   'id': 214575,
#   'main': {'grnd_level': 941.13,
#    'humidity': 95,
#    'pressure': 941.13,
#    'sea_level': 1022.54,
#    'temp': 70.41,
#    'temp_max': 70.41,
#    'temp_min': 70.41},
#   'name': 'Kampene',
#   'sys': {'country': 'CD',
#    'message': 0.1658,
#    'sunrise': 1510977000,
#    'sunset': 1511021246},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 329.005, 'speed': 2.48}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 11.21, 'lon': 99.51},
#   'dt': 1511045553,
#   'id': 1157662,
#   'main': {'grnd_level': 1010.11,
#    'humidity': 93,
#    'pressure': 1010.11,
#    'sea_level': 1022.18,
#    'temp': 78.69,
#    'temp_max': 78.69,
#    'temp_min': 78.69},
#   'name': 'Bang Saphan',
#   'sys': {'country': 'TH',
#    'message': 0.1655,
#    'sunrise': 1510960780,
#    'sunset': 1511002489},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 285.505, 'speed': 6.62}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': 71.92, 'lon': 114.08},
#   'dt': 1511045835,
#   'id': 2017155,
#   'main': {'grnd_level': 1023.97,
#    'humidity': 84,
#    'pressure': 1023.97,
#    'sea_level': 1036.56,
#    'temp': 3.09,
#    'temp_max': 3.09,
#    'temp_min': 3.09},
#   'name': 'Saskylakh',
#   'sys': {'country': 'RU', 'message': 0.166, 'sunrise': 0, 'sunset': 0},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04d',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 16.0046, 'speed': 7.85}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 42.78, 'lon': -9.06},
#   'dt': 1511044200,
#   'id': 3115824,
#   'main': {'humidity': 87,
#    'pressure': 1021,
#    'temp': 48.2,
#    'temp_max': 48.2,
#    'temp_min': 48.2},
#   'name': 'Muros',
#   'sys': {'country': 'ES',
#    'id': 5500,
#    'message': 0.1663,
#    'sunrise': 1510990384,
#    'sunset': 1511024988,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'speed': 2.24}},
#  {'base': 'stations',
#   'clouds': {'all': 24},
#   'cod': 200,
#   'coord': {'lat': -6.88, 'lon': 112.21},
#   'dt': 1511045837,
#   'id': 8079926,
#   'main': {'grnd_level': 1022.19,
#    'humidity': 100,
#    'pressure': 1022.19,
#    'sea_level': 1022.26,
#    'temp': 80.9,
#    'temp_max': 80.9,
#    'temp_min': 80.9},
#   'name': 'Labuhan',
#   'sys': {'country': 'ID',
#    'message': 0.1687,
#    'sunrise': 1510956187,
#    'sunset': 1511000995},
#   'weather': [{'description': 'few clouds',
#     'icon': '02n',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 202.005, 'speed': 6.73}},
#  {'base': 'stations',
#   'clouds': {'all': 48},
#   'cod': 200,
#   'coord': {'lat': -23.7, 'lon': 133.88},
#   'dt': 1511042400,
#   'id': 2077895,
#   'main': {'humidity': 28,
#    'pressure': 1012,
#    'temp': 80.6,
#    'temp_max': 80.6,
#    'temp_min': 80.6},
#   'name': 'Alice Springs',
#   'sys': {'country': 'AU',
#    'id': 8163,
#    'message': 0.1663,
#    'sunrise': 1510949415,
#    'sunset': 1510997376,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 60, 'speed': 8.05}},
#  {'base': 'stations',
#   'clouds': {'all': 64},
#   'cod': 200,
#   'coord': {'lat': 0.96, 'lon': 30.8},
#   'dt': 1511045837,
#   'id': 232834,
#   'main': {'grnd_level': 933.67,
#    'humidity': 100,
#    'pressure': 933.67,
#    'sea_level': 1022.74,
#    'temp': 72.98,
#    'temp_max': 72.98,
#    'temp_min': 72.98},
#   'name': 'Kagadi',
#   'sys': {'country': 'UG',
#    'message': 0.1647,
#    'sunrise': 1510976396,
#    'sunset': 1511019864},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 245.005, 'speed': 5.95}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 43.51, 'lon': 123.51},
#   'dt': 1511045838,
#   'id': 2033135,
#   'main': {'grnd_level': 1023.97,
#    'humidity': 56,
#    'pressure': 1023.97,
#    'sea_level': 1043.54,
#    'temp': 3.09,
#    'temp_max': 3.09,
#    'temp_min': 3.09},
#   'name': 'Zhengjiatun',
#   'sys': {'country': 'CN',
#    'message': 0.2534,
#    'sunrise': 1510958659,
#    'sunset': 1510993069},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 311.505, 'speed': 8.52}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 28.54, 'lon': -80.67},
#   'dt': 1511042280,
#   'id': 4164092,
#   'main': {'humidity': 57,
#    'pressure': 1013,
#    'temp': 75.2,
#    'temp_max': 77,
#    'temp_min': 73.4},
#   'name': 'Merritt Island',
#   'sys': {'country': 'US',
#    'id': 695,
#    'message': 0.1658,
#    'sunrise': 1511005711,
#    'sunset': 1511044049,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 160, 'speed': 5.82}},
#  {'base': 'stations',
#   'clouds': {'all': 32},
#   'cod': 200,
#   'coord': {'lat': -41.87, 'lon': -73.82},
#   'dt': 1511045839,
#   'id': 3899695,
#   'main': {'grnd_level': 1024.05,
#    'humidity': 91,
#    'pressure': 1024.05,
#    'sea_level': 1031.62,
#    'temp': 50.48,
#    'temp_max': 50.48,
#    'temp_min': 50.48},
#   'name': 'Ancud',
#   'sys': {'country': 'CL',
#    'message': 0.169,
#    'sunrise': 1510996889,
#    'sunset': 1511049634},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03d',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 214.005, 'speed': 7.74}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 21.44, 'lon': -157.84},
#   'dt': 1511042220,
#   'id': 5856516,
#   'main': {'humidity': 65,
#    'pressure': 1011,
#    'temp': 78.8,
#    'temp_max': 80.6,
#    'temp_min': 75.2},
#   'name': 'Ahuimanu',
#   'sys': {'country': 'US',
#    'id': 828,
#    'message': 0.1657,
#    'sunrise': 1511023507,
#    'sunset': 1511063305,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03d',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 360, 'speed': 8.05}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 37.47, 'lon': -4.44},
#   'dt': 1511044200,
#   'id': 2520645,
#   'main': {'humidity': 81,
#    'pressure': 1019,
#    'temp': 42.73,
#    'temp_max': 44.6,
#    'temp_min': 41},
#   'name': 'Cabra',
#   'sys': {'country': 'ES',
#    'id': 5467,
#    'message': 0.2445,
#    'sunrise': 1510988491,
#    'sunset': 1511024668,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 144.005, 'speed': 3.15}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': -20.28, 'lon': 44.28},
#   'dt': 1511045840,
#   'id': 1058381,
#   'main': {'grnd_level': 1019.51,
#    'humidity': 92,
#    'pressure': 1019.51,
#    'sea_level': 1025.34,
#    'temp': 77.57,
#    'temp_max': 77.57,
#    'temp_min': 77.57},
#   'name': 'Morondava',
#   'sys': {'country': 'MG',
#    'message': 0.0036,
#    'sunrise': 1510971262,
#    'sunset': 1511018540},
# ...
#   'coord': {'lat': -7.96, 'lon': -79.24},
#   'dt': 1511042400,
#   'id': 3692073,
#   'main': {'humidity': 82,
#    'pressure': 1012,
#    'temp': 66.2,
#    'temp_max': 66.2,
#    'temp_min': 66.2},
#   'name': 'Santiago de Cao',
#   'sys': {'country': 'PE',
#    'id': 4404,
#    'message': 0.1673,
#    'sunrise': 1511002043,
#    'sunset': 1511047050,
#    'type': 1},
#   'visibility': 8000,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04d',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 150, 'speed': 11.41}},
#  {'base': 'stations',
#   'clouds': {'all': 5},
#   'cod': 200,
#   'coord': {'lat': 32.7, 'lon': -103.14},
#   'dt': 1511045400,
#   'id': 5471578,
#   'main': {'humidity': 15,
#    'pressure': 1025,
#    'temp': 56.5,
#    'temp_max': 57.2,
#    'temp_min': 55.4},
#   'name': 'Hobbs',
#   'sys': {'country': 'US',
#    'id': 2016,
#    'message': 0.1655,
#    'sunrise': 1511011586,
#    'sunset': 1511048960,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'clear sky',
#     'icon': '02d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 40, 'gust': 10.3, 'speed': 14.99}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 39.45, 'lon': -86.18},
#   'dt': 1511045100,
#   'id': 4255151,
#   'main': {'humidity': 81,
#    'pressure': 995,
#    'temp': 45.32,
#    'temp_max': 46.4,
#    'temp_min': 44.6},
#   'name': 'Bud',
#   'sys': {'country': 'US',
#    'id': 1025,
#    'message': 0.1651,
#    'sunrise': 1511008401,
#    'sunset': 1511043998,
#    'type': 1},
#   'visibility': 11265,
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'},
#    {'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#   'wind': {'deg': 230, 'gust': 13.4, 'speed': 28.86}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 47.08, 'lon': 8.13},
#   'dt': 1511043600,
#   'id': 2658914,
#   'main': {'humidity': 74,
#    'pressure': 1022,
#    'temp': 36.5,
#    'temp_max': 39.2,
#    'temp_min': 33.8},
#   'name': 'Ruswil',
#   'sys': {'country': 'CH',
#    'id': 6014,
#    'message': 0.2446,
#    'sunrise': 1510987007,
#    'sunset': 1511020110,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'speed': 2.24}},
#  {'base': 'stations',
#   'clouds': {'all': 32},
#   'cod': 200,
#   'coord': {'lat': 46.08, 'lon': 127.4},
#   'dt': 1511046101,
#   'id': 2038421,
#   'main': {'grnd_level': 1019.35,
#    'humidity': 86,
#    'pressure': 1019.35,
#    'sea_level': 1040.21,
#    'temp': -5.96,
#    'temp_max': -5.96,
#    'temp_min': -5.96},
#   'name': 'Bayan',
#   'sys': {'country': 'CN',
#    'message': 0.1744,
#    'sunrise': 1510958169,
#    'sunset': 1510991690},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 271.005, 'speed': 9.08}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': -4.18, 'lon': -38.13},
#   'dt': 1511046000,
#   'id': 3405924,
#   'main': {'humidity': 74,
#    'pressure': 1010,
#    'temp': 80.6,
#    'temp_max': 80.6,
#    'temp_min': 80.6},
#   'name': 'Beberibe',
#   'sys': {'country': 'BR',
#    'id': 4498,
#    'message': 0.0035,
#    'sunrise': 1510992504,
#    'sunset': 1511036851,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#     'icon': '02n',
#     'id': 801,
#     'main': 'Clouds'}],
#   'wind': {'deg': 70, 'speed': 9.17}},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': 9.49, 'lon': 50.81},
#   'dt': 1511046102,
#   'id': 64814,
#   'main': {'grnd_level': 1021.3,
#    'humidity': 100,
#    'pressure': 1021.3,
#    'sea_level': 1026.35,
#    'temp': 78.92,
#    'temp_max': 78.92,
#    'temp_min': 78.92},
#   'name': 'Bandarbeyla',
#   'sys': {'country': 'SO',
#    'message': 0.1643,
#    'sunrise': 1510972322,
#    'sunset': 1511014328},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04n',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 13.0046, 'speed': 21.72}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 24.47, 'lon': 54.37},
#   'dt': 1511042400,
#   'id': 292968,
#   'main': {'humidity': 60,
#    'pressure': 1017,
#    'temp': 73.4,
#    'temp_max': 73.4,
#    'temp_min': 73.4},
#   'name': 'Abu Dhabi',
#   'sys': {'country': 'AE',
#    'id': 7097,
#    'message': 0.166,
#    'sunrise': 1510972855,
#    'sunset': 1511012078,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'speed': 2.24}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 41.76, 'lon': 86.15},
#   'dt': 1511046102,
#   'id': 1529376,
#   'main': {'grnd_level': 905.79,
#    'humidity': 79,
#    'pressure': 905.79,
#    'sea_level': 1048.2,
#    'temp': 14.52,
#    'temp_max': 14.52,
#    'temp_min': 14.52},
#   'name': 'Korla',
#   'sys': {'country': 'CN',
#    'message': 0.1656,
#    'sunrise': 1510967354,
#    'sunset': 1511002311},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 304.505, 'speed': 3.38}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 7.42, 'lon': 81.82},
#   'dt': 1511046103,
#   'id': 1242110,
#   'main': {'grnd_level': 1008.01,
#    'humidity': 99,
#    'pressure': 1008.01,
#    'sea_level': 1023.31,
#    'temp': 71.81,
#    'temp_max': 71.81,
#    'temp_min': 71.81},
#   'name': 'Kalmunai',
#   'sys': {'country': 'LK',
#    'message': 0.1636,
#    'sunrise': 1510964699,
#    'sunset': 1511007065},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 305.005, 'speed': 1.92}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 34.83, 'lon': 137.93},
#   'dt': 1511046104,
#   'id': 1856586,
#   'main': {'grnd_level': 1006.47,
#    'humidity': 93,
#    'pressure': 1006.47,
#    'sea_level': 1027.73,
#    'temp': 45.89,
#    'temp_max': 45.89,
#    'temp_min': 45.89},
#   'name': 'Mori',
#   'sys': {'country': 'JP',
#    'message': 0.1656,
#    'sunrise': 1510953953,
#    'sunset': 1510990858},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 286.005, 'speed': 10.2}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 34.8, 'lon': -106.54},
#   'dt': 1511045700,
#   'id': 5478673,
#   'main': {'humidity': 11,
#    'pressure': 1026,
#    'temp': 50.9,
#    'temp_max': 51.8,
#    'temp_min': 48.2},
#   'name': 'Meadow Lake',
#   'sys': {'country': 'US',
#    'id': 2000,
#    'message': 0.1644,
#    'sunrise': 1511012662,
#    'sunset': 1511049515,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 10, 'speed': 6.93}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 44.16, 'lon': 80},
#   'dt': 1511045761,
#   'id': 1520253,
#   'main': {'grnd_level': 841.91,
#    'humidity': 42,
#    'pressure': 841.91,
#    'sea_level': 1048.12,
#    'temp': -3.53,
#    'temp_max': -3.53,
#    'temp_min': -3.53},
#   'name': 'Zharkent',
#   'sys': {'country': 'KZ',
#    'message': 0.1936,
#    'sunrise': 1510969219,
#    'sunset': 1511003397},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 301.005, 'speed': 2.04}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 5.88, 'lon': -10.05},
#   'dt': 1511042400,
#   'id': 2278158,
#   'main': {'humidity': 94,
#    'pressure': 1011,
#    'temp': 78.8,
#    'temp_max': 78.8,
#    'temp_min': 78.8},
#   'name': 'Buchanan',
#   'sys': {'country': 'LR',
#    'id': 6130,
#    'message': 0.2463,
#    'sunrise': 1510986621,
#    'sunset': 1511029248,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 243.005, 'speed': 4.38}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -43.53, 'lon': 172.63},
#   'dt': 1511044200,
#   'id': 2192362,
#   'main': {'humidity': 59,
#    'pressure': 1022,
#    'temp': 64.4,
#    'temp_max': 64.4,
#    'temp_min': 64.4},
#   'name': 'Christchurch',
#   'sys': {'country': 'NZ',
#    'id': 8278,
#    'message': 0.1666,
#    'sunrise': 1510937489,
#    'sunset': 1510990723,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 90, 'speed': 5.82}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 34.92, 'lon': -81.03},
#   'dt': 1511045700,
#   'id': 4593142,
#   'main': {'humidity': 55,
#    'pressure': 1008,
#    'temp': 63.34,
#    'temp_max': 64.4,
#    'temp_min': 60.8},
#   'name': 'Rock Hill',
#   'sys': {'country': 'US',
#    'id': 2406,
#    'message': 0.169,
#    'sunrise': 1511006550,
#    'sunset': 1511043379,
#    'type': 1},
#   'visibility': 16093,
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 170, 'speed': 3.36}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 27.27, 'lon': 31.15},
#   'dt': 1511042400,
#   'id': 362973,
#   'main': {'humidity': 72,
#    'pressure': 1015,
#    'temp': 59,
#    'temp_max': 59,
#    'temp_min': 59},
#   'name': 'Abnub',
#   'sys': {'country': 'EG',
#    'id': 6387,
#    'message': 0.1688,
#    'sunrise': 1510978723,
#    'sunset': 1511017356,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 340, 'speed': 13.87}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 52.62, 'lon': 8.8},
#   'dt': 1511045400,
#   'id': 2952767,
#   'main': {'humidity': 86,
#    'pressure': 1010,
#    'temp': 39.24,
#    'temp_max': 41,
#    'temp_min': 37.4},
#   'name': 'Barenburg',
#   'sys': {'country': 'DE',
#    'id': 4894,
#    'message': 0.1669,
#    'sunrise': 1510988047,
#    'sunset': 1511018744,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#     'icon': '04n',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 250, 'speed': 11.41}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 15.17, 'lon': 44.32},
#   'dt': 1511046108,
#   'id': 70979,
#   'main': {'grnd_level': 789.39,
#    'humidity': 67,
#    'pressure': 789.39,
#    'sea_level': 1029.63,
#    'temp': 26.63,
#    'temp_max': 26.63,
#    'temp_min': 26.63},
#   'name': 'Sayyan',
#   'sys': {'country': 'YE',
#    'message': 0.1668,
#    'sunrise': 1510974381,
#    'sunset': 1511015381},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 36.5046, 'speed': 2.48}},
#  {'base': 'stations',
#   'clouds': {'all': 32},
#   'cod': 200,
#   'coord': {'lat': 59.38, 'lon': 143.3},
#   'dt': 1511046108,
#   'id': 2122605,
#   'main': {'grnd_level': 1016.35,
#    'humidity': 100,
#    'pressure': 1016.35,
#    'sea_level': 1023.6,
#    'temp': -6.36,
#    'temp_max': -6.36,
#    'temp_min': -6.36},
#   'name': 'Okhotsk',
#   'sys': {'country': 'RU',
#    'message': 0.1657,
#    'sunrise': 1510957789,
#    'sunset': 1510984424},
#   'weather': [{'description': 'scattered clouds',
#     'icon': '03n',
#     'id': 802,
#     'main': 'Clouds'}],
#   'wind': {'deg': 339.505, 'speed': 11.43}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 10.95, 'lon': 106.82},
#   'dt': 1511044200,
#   'id': 1587923,
#   'main': {'humidity': 100,
#    'pressure': 1008,
#    'temp': 77,
#    'temp_max': 77,
#    'temp_min': 77},
#   'name': 'Bien Hoa',
#   'sys': {'country': 'VN',
#    'id': 7985,
#    'message': 0.1665,
#    'sunrise': 1510959002,
#    'sunset': 1511000758,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'speed': 3.36}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 13.2, 'lon': -88.05},
#   'dt': 1511041800,
#   'id': 3585480,
#   'main': {'humidity': 48,
#    'pressure': 1008,
#    'temp': 87.8,
#    'temp_max': 87.8,
#    'temp_min': 87.8},
#   'name': 'Intipuca',
#   'sys': {'country': 'SV',
#    'id': 4207,
#    'message': 0.1751,
#    'sunrise': 1511005984,
#    'sunset': 1511047327,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '01d',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 210, 'speed': 3.36}},
#  {'base': 'stations',
#   'clouds': {'all': 80},
#   'cod': 200,
#   'coord': {'lat': -9.08, 'lon': 143.21},
#   'dt': 1511046110,
#   'id': 2098329,
#   'main': {'grnd_level': 1021.78,
#    'humidity': 100,
#    'pressure': 1021.78,
#    'sea_level': 1023.07,
#    'temp': 79.19,
#    'temp_max': 79.19,
#    'temp_min': 79.19},
#   'name': 'Daru',
#   'rain': {'3h': 0.3575},
#   'sys': {'country': 'PG',
#    'message': 0.1648,
#    'sunrise': 1510948555,
#    'sunset': 1510993746},
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 138.505, 'speed': 9.86}},
#  {'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': 49.96, 'lon': 32.15},
#   'dt': 1511046110,
#   'id': 709643,
#   'main': {'grnd_level': 1012.38,
#    'humidity': 97,
#    'pressure': 1012.38,
#    'sea_level': 1026.47,
#    'temp': 35.31,
#    'temp_max': 35.31,
#    'temp_min': 35.31},
#   'name': 'Drabiv',
#   'rain': {'3h': 0.1175},
#   'sys': {'country': 'UA',
#    'message': 0.0053,
#    'sunrise': 1510981820,
#    'sunset': 1511013763},
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'}],
#   'wind': {'deg': 179.505, 'speed': 6.4}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 49.5, 'lon': -115.07},
#   'dt': 1511042400,
#   'id': 5952370,
#   'main': {'humidity': 59,
#    'pressure': 1021,
#    'temp': 34.75,
#    'temp_max': 35.6,
#    'temp_min': 33.8},
#   'name': 'Fernie',
#   'sys': {'country': 'CA',
#    'id': 3348,
#    'message': 0.1643,
#    'sunrise': 1511017092,
#    'sunset': 1511049168,
#    'type': 1},
#   'visibility': 24140,
#   'weather': [{'description': 'shower rain',
#     'icon': '09d',
#     'id': 521,
#     'main': 'Rain'}],
#   'wind': {'deg': 160, 'gust': 10.8, 'speed': 9.17}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': -32.72, 'lon': 152.15},
#   'dt': 1511044200,
#   'id': 2155562,
#   'main': {'humidity': 60,
#    'pressure': 1022,
#    'temp': 71.6,
#    'temp_max': 71.6,
#    'temp_min': 71.6},
#   'name': 'Nelson Bay',
#   'sys': {'country': 'AU',
#    'id': 8242,
#    'message': 0.0036,
#    'sunrise': 1510944003,
#    'sunset': 1510994025,
#    'type': 1},
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#     'icon': '02n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 110, 'speed': 11.41}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 48.51, 'lon': 34.6},
#   'dt': 1511042880,
#   'id': 709932,
#   'main': {'humidity': 100,
#    'pressure': 1015,
#    'temp': 33.8,
#    'temp_max': 33.8,
#    'temp_min': 33.8},
#   'name': 'Dniprodzerzhynsk',
#   'sys': {'country': 'UA',
#    'id': 7351,
#    'message': 0.1662,
#    'sunrise': 1510980928,
#    'sunset': 1511013480,
#    'type': 1},
#   'visibility': 2900,
#   'weather': [{'description': 'light rain',
#     'icon': '10n',
#     'id': 500,
#     'main': 'Rain'},
#    {'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#   'wind': {'deg': 170, 'speed': 6.71}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 11.05, 'lon': 14.14},
#   'dt': 1511046111,
#   'id': 2225991,
#   'main': {'grnd_level': 976.72,
#    'humidity': 61,
#    'pressure': 976.72,
#    'sea_level': 1021.53,
#    'temp': 68.12,
#    'temp_max': 68.12,
#    'temp_min': 68.12},
#   'name': 'Mora',
#   'sys': {'country': 'CM',
#    'message': 0.1656,
#    'sunrise': 1510981261,
#    'sunset': 1511022993},
#   'weather': [{'description': 'clear sky',
#     'icon': '01n',
#     'id': 800,
#     'main': 'Clear'}],
#   'wind': {'deg': 325.505, 'speed': 3.71}}]

# %%
summary = ["name", "dt", "sys.country", "main.temp_max", "coord.lat", "main.humidity", "clouds.all", "wind.speed"]
data = [response(*summary) for response in weather_data]
column_names = ["City", "Time", "Country", "Temperature", "Latitude", "Humidity", "Cloudiness", "Wind Speed"]
weather_data = pd.DataFrame(data, index=counter, columns=column_names)
weather_data
# Out:
#                  City        Time Country  Temperature  Latitude  Humidity  \
# 1           Tocopilla  1511045803      CL        58.62    -22.09        92
# 2            Frontera  1511041560      MX        84.20     18.58        54
# 3            Portland  1511042160      US        51.80     45.52        62
# 4      Staropyshminsk  1511042400      RU        30.20     56.94        92
# 5             Kapoeta  1511045805      SS        74.01      4.77        43
# 6           Mananjary  1511045805      MG        74.91    -21.22       100
# 7             Ballina  1511045531      AU        70.28    -28.87       100
# 8            Falmouth  1511041800      GB        53.60     50.15        87
# 9             Lerwick  1511043600      GB        42.80     60.15        75
# 10              Ulety  1511045806      RU        14.66     51.36        74
# 11           Gillette  1511041980      US        41.00     44.29        30
# 12              Sidhi  1511045807      IN        68.30     24.42        76
# 13            Fortuna  1511044500      US        55.40     40.60        54
# 14               Dali  1511045533      CN        40.85     25.70       100
# 15     Bobo-Dioulasso  1511042400      BF        80.60     11.18        30
# 16             Burnie  1511045534      AU        61.14    -41.07        92
# 17              Fukue  1511045809      JP        54.39     32.69       100
# 18             Tibiri  1511045810      NE        69.65     13.56        56
# 19          Guangyuan  1511045810      CN        41.75     32.44       100
# 20            Catalao  1511045811      BR        70.41    -18.17        90
# 21         Ust-Omchug  1511045811      RU       -12.08     61.15        70
# 22             Koumac  1511045537      NC        75.23    -20.57        74
# 23         Bani Walid  1511045812      LY        45.26     31.76        84
# 24           Denpasar  1511042400      ID        77.00     -8.65        94
# 25           Udachnyy  1511045813      RU        -9.02     66.42        64
# 26            Masindi  1511045813      UG        64.29      1.67        95
# 27            Varberg  1511043600      SE        44.60     57.11        81
# 28        Mitsamiouli  1511045814      KM        78.87    -11.38       100
# 29         Sao Filipe  1511045815      CV        77.07     14.90       100
# 30             Namibe  1511045815      AO        69.47    -15.20       100
# ..                ...         ...     ...          ...       ...       ...
# 471             Yumen  1511046097      CN        18.17     40.28        80
# 472    Vestmannaeyjar  1511046097      IS        24.47     63.44       100
# 473   Santiago de Cao  1511042400      PE        66.20     -7.96        82
# 474             Hobbs  1511045400      US        57.20     32.70        15
# 475               Bud  1511045100      US        46.40     39.45        81
# 476            Ruswil  1511043600      CH        39.20     47.08        74
# 477             Bayan  1511046101      CN        -5.96     46.08        86
# 478          Beberibe  1511046000      BR        80.60     -4.18        74
# 479       Bandarbeyla  1511046102      SO        78.92      9.49       100
# 480         Abu Dhabi  1511042400      AE        73.40     24.47        60
# 481             Korla  1511046102      CN        14.52     41.76        79
# 482          Kalmunai  1511046103      LK        71.81      7.42        99
# 483              Mori  1511046104      JP        45.89     34.83        93
# 484       Meadow Lake  1511045700      US        51.80     34.80        11
# 485          Zharkent  1511045761      KZ        -3.53     44.16        42
# 486          Buchanan  1511042400      LR        78.80      5.88        94
# 487      Christchurch  1511044200      NZ        64.40    -43.53        59
# 488         Rock Hill  1511045700      US        64.40     34.92        55
# 489             Abnub  1511042400      EG        59.00     27.27        72
# 490         Barenburg  1511045400      DE        41.00     52.62        86
# 491            Sayyan  1511046108      YE        26.63     15.17        67
# 492           Okhotsk  1511046108      RU        -6.36     59.38       100
# 493          Bien Hoa  1511044200      VN        77.00     10.95       100
# 494          Intipuca  1511041800      SV        87.80     13.20        48
# 495              Daru  1511046110      PG        79.19     -9.08       100
# 496            Drabiv  1511046110      UA        35.31     49.96        97
# 497            Fernie  1511042400      CA        35.60     49.50        59
# 498        Nelson Bay  1511044200      AU        71.60    -32.72        60
# 499  Dniprodzerzhynsk  1511042880      UA        33.80     48.51       100
# 500              Mora  1511046111      CM        68.12     11.05        61
#
#      Cloudiness  Wind Speed
# 1             0        4.38
# 2            40        6.93
# 3            75        5.82
# 4            75        8.95
# 5             8        7.40
# 6            92        4.50
# 7            92       13.78
# 8            90       13.87
# 9            44       23.04
# 10           80       10.76
# 11            1        9.17
# 12           88        5.39
# 13            1        4.70
# 14            0        1.92
# 15            0        2.24
# 16            8       17.25
# 17           32       27.54
# 18            0        3.94
# 19           92        2.71
# 20           64        2.82
# 21           64        3.38
# 22           88        4.83
# 23            0        8.86
# 24           40        1.12
# 25           48        3.27
# 26           68        0.47
# 27           92       20.80
# 28           20        8.30
# 29            0       10.98
# 30            0        0.69
# ..          ...         ...
# 471           0        6.96
# 472           0        6.40
# 473          75       11.41
# 474           5       14.99
# 475          90       28.86
# 476          90        2.24
# 477          32        9.08
# 478          20        9.17
# 479          88       21.72
# 480           0        2.24
# 481           0        3.38
# 482           0        1.92
# 483           0       10.20
# 484           1        6.93
# 485           0        2.04
# 486          40        4.38
# 487           0        5.82
# 488          40        3.36
# 489           0       13.87
# 490          75       11.41
# 491           0        2.48
# 492          32       11.43
# 493          75        3.36
# 494           0        3.36
# 495          80        9.86
# 496          88        6.40
# 497          75        9.17
# 498           8       11.41
# 499          90        6.71
# 500           0        3.71
#
# [500 rows x 8 columns]

# %%
cities_list = weather_data

# %%
plt.scatter(weather_data["Latitude"], weather_data["Temperature"], marker="o")


plt.title("City Latitude vs. Max Temperature (11/18/17)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("TemperatureInWorldCities.png")

plt.show()

# %%
plt.scatter(weather_data["Latitude"], weather_data["Cloudiness"], marker="o")

plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("CloudinessInWorldCities.png")

plt.show()

# %%
plt.scatter(weather_data["Latitude"], weather_data["Wind Speed"])

plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt. xlabel("Latitude")
plt.grid(True)
plt.savefig("WindSpeedInWorldCities.png")

plt.show()

# %%
plt.scatter(weather_data["Latitude"], weather_data["Humidity"], marker="o")

plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.savefig("HumidityInWorldCities.png")

plt.show()
